# %% [markdown]
# <a href="https://colab.research.google.com/github/anasantosdev/RP-ACH0042/blob/main/Lens_Brasil_2000_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("LensBrasil2000a2020.xlsx")
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipython-input-2420410365.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_excel("LensBrasil2000a2020.xlsx")
#       5
#       6
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(df_filtered.shape)
# Out:
# (48013, 31)

# %%
display(df_filtered.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48013 entries, 0 to 48012
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            48013 non-null  int64
#  1   Jurisdiction                 48013 non-null  object
#  2   Kind                         48013 non-null  object
#  3   Publication Number           48013 non-null  object
#  4   Lens ID                      48013 non-null  object
#  5   Publication Date             48013 non-null  datetime64[ns]
#  6   Publication Year             48013 non-null  int64
#  7   Application Number           48013 non-null  object
#  8   Application Date             48013 non-null  datetime64[ns]
#  9   Priority Numbers             48013 non-null  object
#  10  Earliest Priority Date       48013 non-null  datetime64[ns]
#  11  Title                        48013 non-null  object
# ...

# %%
df_int64 = df.select_dtypes(include=["int64"])
print(df_int64.head())
# Out:
#    #  Publication Year  Cites Patent Count  Cited by Patent Count  \
# 0  1              2000                   0                      0
# 1  2              2000                   0                      0
# 2  3              2001                   0                      0
# 3  4              2000                   0                      0
# 4  5              2001                   0                      0
#
#    Simple Family Size  Extended Family Size  Sequence Count  \
# 0                   2                     2               0
# 1                   2                     2               0
# 2                   2                     2               0
# 3                   1                     1               0
# 4                   1                     1               0
#
#    NPL Citation Count  NPL Resolved Citation Count
# 0                   0                            0
# 1                   0                            0
# ...

# %%
df_int64_no_idx = df_int64.drop(columns=["#"])
df_int64_no_idx = df_int64_no_idx.reset_index(drop=True)

df_int64_no_idx.head()
# Out:
#    Publication Year  Cites Patent Count  Cited by Patent Count  \
# 0              2000                   0                      0
# 1              2000                   0                      0
# 2              2001                   0                      0
# 3              2000                   0                      0
# 4              2001                   0                      0
#
#    Simple Family Size  Extended Family Size  Sequence Count  \
# 0                   2                     2               0
# 1                   2                     2               0
# 2                   2                     2               0
# 3                   1                     1               0
# 4                   1                     1               0
#
#    NPL Citation Count  NPL Resolved Citation Count
# 0                   0                            0
# 1                   0                            0
# 2                   0                            0
# ...
